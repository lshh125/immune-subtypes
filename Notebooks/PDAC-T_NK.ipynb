# %%
import scanpy as sc
import os
import pandas as pd
import numpy as np
import pickle as pkl
import matplotlib as mpl
import matplotlib.pyplot as plt
import scipy.stats

# %%
sc.settings.verbosity = 3             # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_versions()
sc.settings.set_figure_params(dpi=80, facecolor='white')
# Out:
# scanpy==1.5.1 anndata==0.7.3 umap==0.4.3 numpy==1.18.1 scipy==1.4.1 pandas==1.0.3 scikit-learn==0.22.1 statsmodels==0.11.1
# /home/sliang3/miniconda3/envs/scanpy/lib/python3.8/site-packages/umap/spectral.py:4: NumbaDeprecationWarning: No direct replacement for 'numba.targets' available. Visit https://gitter.im/numba/numba-dev to request help. Thanks!
#   import numba.targets

# %% [markdown]
# # Read Data
#
# Read data using loom

# %%
# adata = sc.read_loom("../data/PDAC/scRNA_fna_SeuratObject_ALL.loom")

# %%
# with open("../data/PDAC/scRNA_fna_SeuratObject_ALL.pkl", 'wb') as file:
#     pkl.dump(obj=adata, file=file)

# %%
with open("../data/PDAC/scRNA_fna_SeuratObject_ALL.pkl", 'rb') as file:
    adata = pkl.load(file)
    
counts = adata[adata.obs.ClusterName.isin(['T', 'NK'])]

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 31720 × 24422
#     obs: 'ClusterID', 'ClusterName', 'G2M_Score', 'Phase', 'S_Score', 'cell_type', 'integrated_snn_res_0_5', 'nCount_RNA', 'nFeature_RNA', 'orig_ident', 'percent_mt', 'seurat_clusters', 'stage'
#     var: 'Selected', 'vst_mean', 'vst_variable', 'vst_variance', 'vst_variance_expected', 'vst_variance_standardized'
#     layers: 'norm_data'

# %%
adata.obs
# Out:
#                       ClusterID ClusterName  G2M_Score Phase   S_Score  \
# AAACCTGGTTCCCTTG_1            3     Myeloid  -0.139026    G1 -0.102319
# AAACGGGCAATCCGAT_1            3     Myeloid   0.005527   G2M -0.019100
# AAACGGGTCGAATCCA_1            2           T   0.014605   G2M -0.015689
# AAAGATGTCCACTCCA_1            2           T  -0.022346     S  0.006563
# AAAGATGTCTGCGTAA_1            2           T  -0.025140     S  0.003153
# ...                         ...         ...        ...   ...       ...
# attagtatagcgcgttat_9          1  Epithelial  -0.015158    G1 -0.012173
# ccacgcgtacagaccttc_9          1  Epithelial   0.001490     S  0.081848
# gctcccagtaaaggtagg_9          1  Epithelial  -0.011416    G1 -0.010956
# tgaatttgcggtgtacag_9          1  Epithelial  -0.031338    G1 -0.006695
# gcgaatgtggtggccgtt_9          3     Myeloid  -0.015626    G1 -0.008521
#
#                        cell_type integrated_snn_res_0_5  nCount_RNA  \
# AAACCTGGTTCCCTTG_1       Myeloid                      8      7110.0
# AAACGGGCAATCCGAT_1       Myeloid                     11       862.0
# AAACGGGTCGAATCCA_1             T                      3       919.0
# AAAGATGTCCACTCCA_1             T                      3      1432.0
# AAAGATGTCTGCGTAA_1             T                      0      1675.0
# ...                          ...                    ...         ...
# attagtatagcgcgttat_9  Epithelial                      6       449.0
# ccacgcgtacagaccttc_9  Epithelial                      6       448.0
# gctcccagtaaaggtagg_9  Epithelial                      5       446.0
# tgaatttgcggtgtacag_9  Epithelial                      2       446.0
# gcgaatgtggtggccgtt_9     Myeloid                     11       445.0
#
#                       nFeature_RNA orig_ident  percent_mt seurat_clusters  \
# AAACCTGGTTCCCTTG_1            2112         P1    4.289733               8
# AAACGGGCAATCCGAT_1             436         P1   29.118330              11
# AAACGGGTCGAATCCA_1             484         P1    7.508161               3
# AAAGATGTCCACTCCA_1             706         P1    7.262570               3
# AAAGATGTCTGCGTAA_1             686         P1    4.059701               0
# ...                            ...        ...         ...             ...
# attagtatagcgcgttat_9           269         PM    0.000000               6
# ccacgcgtacagaccttc_9           272         PM    0.000000               6
# gctcccagtaaaggtagg_9           293         PM    0.000000               5
# tgaatttgcggtgtacag_9           291         PM    0.000000               2
# gcgaatgtggtggccgtt_9           266         PM    0.000000              11
#
#                            stage
# AAACCTGGTTCCCTTG_1       Primary
# AAACGGGCAATCCGAT_1       Primary
# AAACGGGTCGAATCCA_1       Primary
# AAAGATGTCCACTCCA_1       Primary
# AAAGATGTCTGCGTAA_1       Primary
# ...                          ...
# attagtatagcgcgttat_9  Metastasis
# ccacgcgtacagaccttc_9  Metastasis
# gctcccagtaaaggtagg_9  Metastasis
# tgaatttgcggtgtacag_9  Metastasis
# gcgaatgtggtggccgtt_9  Metastasis
#
# [31720 rows x 13 columns]

# %% [markdown]
# # T and NK cells

# %%
lymphocytes = adata[adata.obs.ClusterName.isin(['T', 'NK'])]
lymphocytes
# Out:
# View of AnnData object with n_obs × n_vars = 10535 × 24422
#     obs: 'ClusterID', 'ClusterName', 'G2M_Score', 'Phase', 'S_Score', 'cell_type', 'integrated_snn_res_0_5', 'nCount_RNA', 'nFeature_RNA', 'orig_ident', 'percent_mt', 'seurat_clusters', 'stage'
#     var: 'Selected', 'vst_mean', 'vst_variable', 'vst_variance', 'vst_variance_expected', 'vst_variance_standardized'
#     layers: 'norm_data'

# %%
sc.pl.highest_expr_genes(lymphocytes, n_top=20)
# Out:
# /home/sliang3/miniconda3/envs/scanpy/lib/python3.8/site-packages/scanpy/preprocessing/_normalization.py:138: UserWarning: Revieved a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# normalizing counts per cell
#     finished (0:00:00)

# %%
sc.pp.filter_cells(lymphocytes, min_genes=200)
sc.pp.filter_genes(lymphocytes, min_cells=3)
# Out:
# filtered out 7017 genes that are detected in less than 3 cells

# %%
lymphocytes.var['mt'] = lymphocytes.var.index.str.startswith('MT-')  # annotate the group of mitochondrial genes as 'mt'
sc.pp.calculate_qc_metrics(lymphocytes, qc_vars=['mt'], percent_top=None, log1p=False, inplace=True)
sc.pl.violin(lymphocytes, ['n_genes_by_counts', 'total_counts', 'pct_counts_mt'], jitter=0.4, multi_panel=True)

# %%
sc.pl.scatter(lymphocytes, x='total_counts', y='pct_counts_mt')
sc.pl.scatter(lymphocytes, x='total_counts', y='n_genes_by_counts')

# %%
lymphocytes = lymphocytes[(lymphocytes.obs.pct_counts_mt < 20) & (lymphocytes.obs.n_genes_by_counts < 4000) , :]
lymphocytes.raw = lymphocytes
lymphocytes
# Out:
# AnnData object with n_obs × n_vars = 10459 × 17405
#     obs: 'ClusterID', 'ClusterName', 'G2M_Score', 'Phase', 'S_Score', 'cell_type', 'integrated_snn_res_0_5', 'nCount_RNA', 'nFeature_RNA', 'orig_ident', 'percent_mt', 'seurat_clusters', 'stage', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt'
#     var: 'Selected', 'vst_mean', 'vst_variable', 'vst_variance', 'vst_variance_expected', 'vst_variance_standardized', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     layers: 'norm_data'

# %%
sc.pp.normalize_total(lymphocytes, target_sum=1e4)
sc.pp.log1p(lymphocytes)
sc.pp.scale(lymphocytes, max_value=10)
# Out:
# normalizing counts per cell
#     finished (0:00:00)
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption

# %%
sc.pp.highly_variable_genes(lymphocytes, min_mean=0.0125, max_mean=3, min_disp=0.5)
sc.pl.highly_variable_genes(lymphocytes)
# Out:
# extracting highly variable genes
#     finished (0:00:03)
# --> added
#     'highly_variable', boolean vector (adata.var)
#     'means', float vector (adata.var)
#     'dispersions', float vector (adata.var)
#     'dispersions_norm', float vector (adata.var)

# %%
lymphocytes = lymphocytes[:, lymphocytes.var.highly_variable]
lymphocytes
# Out:
# View of AnnData object with n_obs × n_vars = 10459 × 3874
#     obs: 'ClusterID', 'ClusterName', 'G2M_Score', 'Phase', 'S_Score', 'cell_type', 'integrated_snn_res_0_5', 'nCount_RNA', 'nFeature_RNA', 'orig_ident', 'percent_mt', 'seurat_clusters', 'stage', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt'
#     var: 'Selected', 'vst_mean', 'vst_variable', 'vst_variance', 'vst_variance_expected', 'vst_variance_standardized', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'mean', 'std', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'log1p'
#     layers: 'norm_data'

# %% [markdown]
# # Dimensional Reduction

# %% [markdown]
# ## PCA

# %%
sc.tl.pca(lymphocytes, svd_solver='arpack')
sc.pl.pca(lymphocytes, color='cell_type', legend_loc='on data')
# Out:
# computing PCA
#     on highly variable genes
#     with n_comps=50
#     finished (0:00:05)

# %%
sc.pl.pca_variance_ratio(lymphocytes, log=True)

# %%
sc.tl.rank_genes_groups(lymphocytes, 'cell_type', method='wilcoxon')
sc.pl.rank_genes_groups(lymphocytes, n_genes=25, sharey=False)
# Out:
# ranking genes
#     finished: added to `.uns['rank_genes_groups']`
#     'names', sorted np.recarray to be indexed by group ids
#     'scores', sorted np.recarray to be indexed by group ids
#     'logfoldchanges', sorted np.recarray to be indexed by group ids
#     'pvals', sorted np.recarray to be indexed by group ids
#     'pvals_adj', sorted np.recarray to be indexed by group ids (0:00:16)

# %% [markdown]
# ## UMAP

# %%
sc.pp.neighbors(lymphocytes)
# Out:
# computing neighbors
#     using 'X_pca' with n_pcs = 50
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:09)

# %%
sc.tl.umap(lymphocytes)
# Out:
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:08)

# %%
sc.pl.umap(lymphocytes, color='cell_type', legend_loc='on data')

# %%
markers = ["GNLY", "CD3G", "IL23R", "ID2", "PCDH9"]
sc.pl.umap(lymphocytes.raw.to_adata(), color=markers, legend_loc='on data', frameon=False, ncols=3)

# %%
il23r = lymphocytes.raw[:, 'IL23R'].X.todense() > 0
pcdh9 = lymphocytes.raw[:, 'PCDH9'].X.todense() > 0

contingency_table = pd.DataFrame([[(~il23r & ~pcdh9).sum(), il23r.sum()], [pcdh9.sum(), (il23r & pcdh9).sum()]],
                                 index=['PCDH9-', 'PCDH9+'],
                                 columns=["IL23R-", "IL23R+"])
display(contingency_table)
chi2, p, dof, ex = scipy.stats.chi2_contingency(contingency_table)
print(f"χ² = {chi2:.2f}, p = {p:.2e}")
# Out:
#         IL23R-  IL23R+
# PCDH9-   10325     112
# PCDH9+      25       3
# χ² = 15.84, p = 6.91e-05

# %%
def phi(tab):
    return ((tab[0][0] * tab[1][1] - 
             tab[0][1] * tab[1][0]) / 
            ((tab[0][0] + tab[0][1]) * 
             (tab[1][0] + tab[1][1]) *
             (tab[0][0] + tab[1][0]) *
             (tab[0][1] + tab[1][1]) ) ** .5)

# %%
scipy.stats.chi2_contingency([[0, 100], [100, 0]])
# Out:
# (196.02,
#  1.5431200214053197e-44,
#  1,
#  array([[50., 50.],
#         [50., 50.]]))

# %%
markers = ["GATA3", "ID2", "RORA"]
sc.pl.umap(lymphocytes.raw.to_adata(), color=markers, legend_loc='on data', frameon=False, ncols=4)

# %%
gata3 = lymphocytes.raw[:, 'GATA3'].X.todense() > 0
id2 = lymphocytes.raw[:, 'ID2'].X.todense() > 0
rora = lymphocytes.raw[:, 'RORA'].X.todense() > 0

# %%
il23r = lymphocytes.raw[:, 'IL23R'].X.todense() > 0
pcdh9 = lymphocytes.raw[:, 'PCDH9'].X.todense() > 0

contingency_table = pd.DataFrame([[(~il23r & ~pcdh9).sum(), il23r.sum()], [pcdh9.sum(), (il23r & pcdh9).sum()]],
                                 index=['PCDH9-', 'PCDH9+'],
                                 columns=["IL23R-", "IL23R+"])
display(contingency_table)
chi2, p, dof, ex = scipy.stats.chi2_contingency(contingency_table)
print(f"χ² = {chi2:.2f}, p = {p:.2e}")

# %%
test_genes = ['GATA3', "ID2", "RORA"]
p_df = pd.DataFrame(index=test_genes, columns=test_genes)
phi_df = pd.DataFrame(index=test_genes, columns=test_genes)
for i, gene1 in enumerate(test_genes):
    for gene2 in test_genes[i+1:]:
        try:
            var1 = lymphocytes.raw[:, gene1].X.todense() > 0
            var2 = lymphocytes.raw[:, gene2].X.todense() > 0
            tab = [[(~var1 & ~var2).sum(), var1.sum()], [var2.sum(), (var1 & var2).sum()]]
            chi2, p, dof, ex = scipy.stats.chi2_contingency(tab)
            p_df.loc[gene1, gene2] = p_df.loc[gene2, gene1] = p
            phi_df.loc[gene1, gene2] = phi_df.loc[gene2, gene1] = phi(tab)
        except ValueError:
            pass
        
display(p_df)
display(phi_df)
# Out:
#               GATA3           ID2          RORA
# GATA3           NaN  6.22485e-171   1.93942e-36
# ID2    6.22485e-171           NaN  2.05066e-162
# RORA    1.93942e-36  2.05066e-162           NaN
#           GATA3       ID2      RORA
# GATA3       NaN -0.238165 -0.112835
# ID2   -0.238165       NaN -0.230459
# RORA  -0.112835 -0.230459       NaN

# %%
tab
# Out:
# [[3642, 5434], [3106, 1723]]

# %%
# all_genes = lymphocytes.raw.var_names
# distr = pd.DataFrame(index=all_genes, columns=all_genes)
# for i, gene1 in enumerate(all_genes):
#     for gene2 in all_genes[i:]:
#         try:
#             temp = chi2(lymphocytes.raw[:, gene1].X.todense() > 0, lymphocytes.raw[:, gene2].X.todense() > 0)
#             distr.loc[gene1, gene2] = distr.loc[gene2, gene1] = temp
#         except ValueError:
#             pass

# %%
distr.iloc[1000]
# Out:
# FO538757.2       0.764546
# AP006222.2       0.357581
# RP4-669L17.10    0.930547
# RP11-206L10.9    0.682354
# LINC00115        0.618022
#                    ...
# RNA45S5               NaN
# UQCRBP1               NaN
# FLJ44635              NaN
# PRKY                  NaN
# TXLNGY                NaN
# Name: SHC1, Length: 17405, dtype: object

# %%
temp = lymphocytes.raw.to_adata().copy()
sc.pp.filter_genes(temp, min_cells=1)

n_sample_gene_pairs = 10000
n_genes = temp.n_vars

res = []

def chi2(var1, var2):
    chi2, p, dof, ex = scipy.stats.chi2_contingency([[(~var1 & ~var2).sum(), var1.sum()], [var2.sum(), (var1 & var2).sum()]])
    return p

for num in np.random.randint(0, n_genes * n_genes, n_sample_gene_pairs):
    gene1 = temp.var_names[num % n_genes]
    gene2 = temp.var_names[num // n_genes]
    res.append(chi2(lymphocytes.raw[:, gene1].X.todense() > 0, lymphocytes.raw[:, gene2].X.todense() > 0))
# Out:
# filtered out 1397 genes that are detected in less than 5 cells

# %%
plt.hist(res, bins=100)
# Out:
# (array([1623.,  184.,  111.,  103.,  109.,   84.,   74.,   81.,   78.,
#           88.,   59.,   75.,   66.,   75.,   70.,   68.,   68.,   61.,
#           58.,   74.,   57.,   69.,   66.,   75.,   60.,   51.,   58.,
#           66.,   76.,   74.,   59.,   76.,   67.,   67.,   60.,   44.,
#           65.,   61.,   78.,   58.,   72.,   60.,   60.,   64.,   58.,
#           73.,   71.,   66.,   69.,   63.,   69.,   64.,   73.,   62.,
#           54.,   70.,   55.,   70.,   50.,   74.,   79.,   89.,   88.,
#          103.,   78.,   73.,   71.,   86.,   91.,   83.,   98.,   84.,
#           94.,   94.,  102.,  110.,   97.,   93.,   90.,   83.,   99.,
#          117.,  112.,  125.,  113.,  132.,   94.,  107.,  122.,  110.,
#          107.,  107.,  132.,  122.,  133.,  130.,  156.,  129.,  119.,
#          155.]),
#  array([0.        , 0.00999727, 0.01999454, 0.02999182, 0.03998909,
#         0.04998636, 0.05998363, 0.0699809 , 0.07997817, 0.08997545,
#         0.09997272, 0.10996999, 0.11996726, 0.12996453, 0.13996181,
#         0.14995908, 0.15995635, 0.16995362, 0.17995089, 0.18994816,
#         0.19994544, 0.20994271, 0.21993998, 0.22993725, 0.23993452,
#         0.2499318 , 0.25992907, 0.26992634, 0.27992361, 0.28992088,
#         0.29991815, 0.30991543, 0.3199127 , 0.32990997, 0.33990724,
#         0.34990451, 0.35990179, 0.36989906, 0.37989633, 0.3898936 ,
#         0.39989087, 0.40988814, 0.41988542, 0.42988269, 0.43987996,
#         0.44987723, 0.4598745 , 0.46987178, 0.47986905, 0.48986632,
#         0.49986359, 0.50986086, 0.51985813, 0.52985541, 0.53985268,
#         0.54984995, 0.55984722, 0.56984449, 0.57984177, 0.58983904,
#         0.59983631, 0.60983358, 0.61983085, 0.62982812, 0.6398254 ,
#         0.64982267, 0.65981994, 0.66981721, 0.67981448, 0.68981176,
#         0.69980903, 0.7098063 , 0.71980357, 0.72980084, 0.73979811,
#         0.74979539, 0.75979266, 0.76978993, 0.7797872 , 0.78978447,
#         0.79978175, 0.80977902, 0.81977629, 0.82977356, 0.83977083,
#         0.8497681 , 0.85976538, 0.86976265, 0.87975992, 0.88975719,
#         0.89975446, 0.90975174, 0.91974901, 0.92974628, 0.93974355,
#         0.94974082, 0.95973809, 0.96973537, 0.97973264, 0.98972991,
#         0.99972718]),
#  <a list of 100 Patch objects>)

# %%
test_genes = ['IL7R', "CD3G", "PTGDR", "KLRC1", "FCGR3A", "FCGR3B"]
p_df = pd.DataFrame(index=test_genes, columns=test_genes)
phi_df = pd.DataFrame(index=test_genes, columns=test_genes)
for i, gene1 in enumerate(test_genes):
    for gene2 in test_genes[i+1:]:
        try:
            var1 = lymphocytes.raw[:, gene1].X.todense() > 0
            var2 = lymphocytes.raw[:, gene2].X.todense() > 0
            tab = [[(~var1 & ~var2).sum(), var1.sum()], [var2.sum(), (var1 & var2).sum()]]
            chi2, p, dof, ex = scipy.stats.chi2_contingency(tab)
            p_df.loc[gene1, gene2] = p_df.loc[gene2, gene1] = p
            phi_df.loc[gene1, gene2] = phi_df.loc[gene2, gene1] = phi(tab)
        except ValueError:
            pass
        
display(p_df.style.format("{:.2e}"))
display(phi_df.style.format("{:.2f}"))
# Out:
# <style  type="text/css" >
# </style><table id="T_82a91414_ace0_11ea_b932_0de61858c94e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >IL7R</th>        <th class="col_heading level0 col1" >CD3G</th>        <th class="col_heading level0 col2" >PTGDR</th>        <th class="col_heading level0 col3" >KLRC1</th>        <th class="col_heading level0 col4" >FCGR3A</th>        <th class="col_heading level0 col5" >FCGR3B</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_82a91414_ace0_11ea_b932_0de61858c94elevel0_row0" class="row_heading level0 row0" >IL7R</th>
#                         <td id="T_82a91414_ace0_11ea_b932_0de61858c94erow0_col0" class="data row0 col0" >nan</td>
#                         <td id="T_82a91414_ace0_11ea_b932_0de61858c94erow0_col1" class="data row0 col1" >0.00e+00</td>
#                         <td id="T_82a91414_ace0_11ea_b932_0de61858c94erow0_col2" class="data row0 col2" >5.68e-269</td>
#                         <td id="T_82a91414_ace0_11ea_b932_0de61858c94erow0_col3" class="data row0 col3" >1.74e-128</td>
#                         <td id="T_82a91414_ace0_11ea_b932_0de61858c94erow0_col4" class="data row0 col4" >0.00e+00</td>
#                         <td id="T_82a91414_ace0_11ea_b932_0de61858c94erow0_col5" class="data row0 col5" >3.90e-20</td>
#             </tr>
#             <tr>
#                         <th id="T_82a91414_ace0_11ea_b932_0de61858c94elevel0_row1" class="row_heading level0 row1" >CD3G</th>
#                         <td id="T_82a91414_ace0_11ea_b932_0de61858c94erow1_col0" class="data row1 col0" >0.00e+00</td>
#                         <td id="T_82a91414_ace0_11ea_b932_0de61858c94erow1_col1" class="data row1 col1" >nan</td>
#                         <td id="T_82a91414_ace0_11ea_b932_0de61858c94erow1_col2" class="data row1 col2" >7.01e-150</td>
#                         <td id="T_82a91414_ace0_11ea_b932_0de61858c94erow1_col3" class="data row1 col3" >9.47e-98</td>
#                         <td id="T_82a91414_ace0_11ea_b932_0de61858c94erow1_col4" class="data row1 col4" >4.43e-209</td>
#                         <td id="T_82a91414_ace0_11ea_b932_0de61858c94erow1_col5" class="data row1 col5" >3.51e-11</td>
#             </tr>
#             <tr>
#                         <th id="T_82a91414_ace0_11ea_b932_0de61858c94elevel0_row2" class="row_heading level0 row2" >PTGDR</th>
#                         <td id="T_82a91414_ace0_11ea_b932_0de61858c94erow2_col0" class="data row2 col0" >5.68e-269</td>
#                         <td id="T_82a91414_ace0_11ea_b932_0de61858c94erow2_col1" class="data row2 col1" >7.01e-150</td>
#                         <td id="T_82a91414_ace0_11ea_b932_0de61858c94erow2_col2" class="data row2 col2" >nan</td>
#                         <td id="T_82a91414_ace0_11ea_b932_0de61858c94erow2_col3" class="data row2 col3" >6.24e-23</td>
#                         <td id="T_82a91414_ace0_11ea_b932_0de61858c94erow2_col4" class="data row2 col4" >1.41e-38</td>
#                         <td id="T_82a91414_ace0_11ea_b932_0de61858c94erow2_col5" class="data row2 col5" >3.70e-06</td>
#             </tr>
#             <tr>
#                         <th id="T_82a91414_ace0_11ea_b932_0de61858c94elevel0_row3" class="row_heading level0 row3" >KLRC1</th>
#                         <td id="T_82a91414_ace0_11ea_b932_0de61858c94erow3_col0" class="data row3 col0" >1.74e-128</td>
#                         <td id="T_82a91414_ace0_11ea_b932_0de61858c94erow3_col1" class="data row3 col1" >9.47e-98</td>
#                         <td id="T_82a91414_ace0_11ea_b932_0de61858c94erow3_col2" class="data row3 col2" >6.24e-23</td>
#                         <td id="T_82a91414_ace0_11ea_b932_0de61858c94erow3_col3" class="data row3 col3" >nan</td>
#                         <td id="T_82a91414_ace0_11ea_b932_0de61858c94erow3_col4" class="data row3 col4" >1.63e-43</td>
#                         <td id="T_82a91414_ace0_11ea_b932_0de61858c94erow3_col5" class="data row3 col5" >1.14e-02</td>
#             </tr>
#             <tr>
#                         <th id="T_82a91414_ace0_11ea_b932_0de61858c94elevel0_row4" class="row_heading level0 row4" >FCGR3A</th>
#                         <td id="T_82a91414_ace0_11ea_b932_0de61858c94erow4_col0" class="data row4 col0" >0.00e+00</td>
#                         <td id="T_82a91414_ace0_11ea_b932_0de61858c94erow4_col1" class="data row4 col1" >4.43e-209</td>
#                         <td id="T_82a91414_ace0_11ea_b932_0de61858c94erow4_col2" class="data row4 col2" >1.41e-38</td>
#                         <td id="T_82a91414_ace0_11ea_b932_0de61858c94erow4_col3" class="data row4 col3" >1.63e-43</td>
#                         <td id="T_82a91414_ace0_11ea_b932_0de61858c94erow4_col4" class="data row4 col4" >nan</td>
#                         <td id="T_82a91414_ace0_11ea_b932_0de61858c94erow4_col5" class="data row4 col5" >4.02e-34</td>
#             </tr>
#             <tr>
#                         <th id="T_82a91414_ace0_11ea_b932_0de61858c94elevel0_row5" class="row_heading level0 row5" >FCGR3B</th>
#                         <td id="T_82a91414_ace0_11ea_b932_0de61858c94erow5_col0" class="data row5 col0" >3.90e-20</td>
#                         <td id="T_82a91414_ace0_11ea_b932_0de61858c94erow5_col1" class="data row5 col1" >3.51e-11</td>
#                         <td id="T_82a91414_ace0_11ea_b932_0de61858c94erow5_col2" class="data row5 col2" >3.70e-06</td>
#                         <td id="T_82a91414_ace0_11ea_b932_0de61858c94erow5_col3" class="data row5 col3" >1.14e-02</td>
#                         <td id="T_82a91414_ace0_11ea_b932_0de61858c94erow5_col4" class="data row5 col4" >4.02e-34</td>
#                         <td id="T_82a91414_ace0_11ea_b932_0de61858c94erow5_col5" class="data row5 col5" >nan</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
# </style><table id="T_82a9e61e_ace0_11ea_b932_0de61858c94e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >IL7R</th>        <th class="col_heading level0 col1" >CD3G</th>        <th class="col_heading level0 col2" >PTGDR</th>        <th class="col_heading level0 col3" >KLRC1</th>        <th class="col_heading level0 col4" >FCGR3A</th>        <th class="col_heading level0 col5" >FCGR3B</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_82a9e61e_ace0_11ea_b932_0de61858c94elevel0_row0" class="row_heading level0 row0" >IL7R</th>
#                         <td id="T_82a9e61e_ace0_11ea_b932_0de61858c94erow0_col0" class="data row0 col0" >nan</td>
#                         <td id="T_82a9e61e_ace0_11ea_b932_0de61858c94erow0_col1" class="data row0 col1" >-0.30</td>
#                         <td id="T_82a9e61e_ace0_11ea_b932_0de61858c94erow0_col2" class="data row0 col2" >-0.33</td>
#                         <td id="T_82a9e61e_ace0_11ea_b932_0de61858c94erow0_col3" class="data row0 col3" >-0.23</td>
#                         <td id="T_82a9e61e_ace0_11ea_b932_0de61858c94erow0_col4" class="data row0 col4" >-0.39</td>
#                         <td id="T_82a9e61e_ace0_11ea_b932_0de61858c94erow0_col5" class="data row0 col5" >-0.09</td>
#             </tr>
#             <tr>
#                         <th id="T_82a9e61e_ace0_11ea_b932_0de61858c94elevel0_row1" class="row_heading level0 row1" >CD3G</th>
#                         <td id="T_82a9e61e_ace0_11ea_b932_0de61858c94erow1_col0" class="data row1 col0" >-0.30</td>
#                         <td id="T_82a9e61e_ace0_11ea_b932_0de61858c94erow1_col1" class="data row1 col1" >nan</td>
#                         <td id="T_82a9e61e_ace0_11ea_b932_0de61858c94erow1_col2" class="data row1 col2" >-0.24</td>
#                         <td id="T_82a9e61e_ace0_11ea_b932_0de61858c94erow1_col3" class="data row1 col3" >-0.20</td>
#                         <td id="T_82a9e61e_ace0_11ea_b932_0de61858c94erow1_col4" class="data row1 col4" >-0.30</td>
#                         <td id="T_82a9e61e_ace0_11ea_b932_0de61858c94erow1_col5" class="data row1 col5" >-0.07</td>
#             </tr>
#             <tr>
#                         <th id="T_82a9e61e_ace0_11ea_b932_0de61858c94elevel0_row2" class="row_heading level0 row2" >PTGDR</th>
#                         <td id="T_82a9e61e_ace0_11ea_b932_0de61858c94erow2_col0" class="data row2 col0" >-0.33</td>
#                         <td id="T_82a9e61e_ace0_11ea_b932_0de61858c94erow2_col1" class="data row2 col1" >-0.24</td>
#                         <td id="T_82a9e61e_ace0_11ea_b932_0de61858c94erow2_col2" class="data row2 col2" >nan</td>
#                         <td id="T_82a9e61e_ace0_11ea_b932_0de61858c94erow2_col3" class="data row2 col3" >0.09</td>
#                         <td id="T_82a9e61e_ace0_11ea_b932_0de61858c94erow2_col4" class="data row2 col4" >0.12</td>
#                         <td id="T_82a9e61e_ace0_11ea_b932_0de61858c94erow2_col5" class="data row2 col5" >0.05</td>
#             </tr>
#             <tr>
#                         <th id="T_82a9e61e_ace0_11ea_b932_0de61858c94elevel0_row3" class="row_heading level0 row3" >KLRC1</th>
#                         <td id="T_82a9e61e_ace0_11ea_b932_0de61858c94erow3_col0" class="data row3 col0" >-0.23</td>
#                         <td id="T_82a9e61e_ace0_11ea_b932_0de61858c94erow3_col1" class="data row3 col1" >-0.20</td>
#                         <td id="T_82a9e61e_ace0_11ea_b932_0de61858c94erow3_col2" class="data row3 col2" >0.09</td>
#                         <td id="T_82a9e61e_ace0_11ea_b932_0de61858c94erow3_col3" class="data row3 col3" >nan</td>
#                         <td id="T_82a9e61e_ace0_11ea_b932_0de61858c94erow3_col4" class="data row3 col4" >0.13</td>
#                         <td id="T_82a9e61e_ace0_11ea_b932_0de61858c94erow3_col5" class="data row3 col5" >0.03</td>
#             </tr>
#             <tr>
#                         <th id="T_82a9e61e_ace0_11ea_b932_0de61858c94elevel0_row4" class="row_heading level0 row4" >FCGR3A</th>
#                         <td id="T_82a9e61e_ace0_11ea_b932_0de61858c94erow4_col0" class="data row4 col0" >-0.39</td>
#                         <td id="T_82a9e61e_ace0_11ea_b932_0de61858c94erow4_col1" class="data row4 col1" >-0.30</td>
#                         <td id="T_82a9e61e_ace0_11ea_b932_0de61858c94erow4_col2" class="data row4 col2" >0.12</td>
#                         <td id="T_82a9e61e_ace0_11ea_b932_0de61858c94erow4_col3" class="data row4 col3" >0.13</td>
#                         <td id="T_82a9e61e_ace0_11ea_b932_0de61858c94erow4_col4" class="data row4 col4" >nan</td>
#                         <td id="T_82a9e61e_ace0_11ea_b932_0de61858c94erow4_col5" class="data row4 col5" >0.12</td>
#             </tr>
#             <tr>
#                         <th id="T_82a9e61e_ace0_11ea_b932_0de61858c94elevel0_row5" class="row_heading level0 row5" >FCGR3B</th>
#                         <td id="T_82a9e61e_ace0_11ea_b932_0de61858c94erow5_col0" class="data row5 col0" >-0.09</td>
#                         <td id="T_82a9e61e_ace0_11ea_b932_0de61858c94erow5_col1" class="data row5 col1" >-0.07</td>
#                         <td id="T_82a9e61e_ace0_11ea_b932_0de61858c94erow5_col2" class="data row5 col2" >0.05</td>
#                         <td id="T_82a9e61e_ace0_11ea_b932_0de61858c94erow5_col3" class="data row5 col3" >0.03</td>
#                         <td id="T_82a9e61e_ace0_11ea_b932_0de61858c94erow5_col4" class="data row5 col4" >0.12</td>
#                         <td id="T_82a9e61e_ace0_11ea_b932_0de61858c94erow5_col5" class="data row5 col5" >nan</td>
#             </tr>
#     </tbody></table>
